# %%
# import libs
import pymongo
import csv

# %%
# Get Mongo db Instance
_mongo_uri = "mongodb://tenet_api:6k5s0g20rMb6wCMe@tenet-shard-00-00.vm7su.mongodb.net:27017,tenet-shard-00-01.vm7su.mongodb.net:27017,tenet-shard-00-02.vm7su.mongodb.net:27017/tenet?ssl=true&replicaSet=atlas-30piss-shard-0&authSource=admin&retryWrites=true&w=majority"
_db_name = "tenet"
_db_doc = "tweets"
client = pymongo.MongoClient(_mongo_uri)
db = client[_db_name]
doc = db[_db_doc]

# %%
# Fetch data
_obj = {"polarity == trans_polarity"}
tweets = doc.find({ "$expr": { "$ne": [ "$polarity" , "$trans_polarity" ] } })

with open('small_db.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    # header
    writer.writerow(['S. No.', 'Text', 'Trasnlated Text', 'Polarity', 'Trasnlated Polarity'])
    _count = 0
    for row in tweets:        
        try:
            writer.writerow([_count, row['tweet'], row['trans_text'],row['polarity'],row['trans_polarity']])
            _count += 1
            print(row)
        except:
            continue        
print("CSV Closed!!")
# Out:
# {'_id': ObjectId('607e627c0673de6780cc6e7e'), 'tweet': 'eikebatista especulouse que ap s a pandemia da covid19 o novo normal para as empresas do vale do sil cio seria uma for a de trabalho altamente orientada para o remoto com apenas uma equipe m nima no escrit rio parece cada vez mais claro que isso n o vai acontecer 5', 'lang': 'pt', 'polarity': 0.15, 'trans_polarity': 0.10927272727272727, 'trans_text': 'Eikebatista speculated that after the pandemic of covid19 the new normal for the companies of the Valley of Sil CIO would be a working highly oriented work with only one team m nima in the office river seems increasingly clear that this will happen 5 '}
# ...

# %%
# // Final Cell
# # import libs
# import pymongo
# import csv

# # Get Mongo db Instance
# _mongo_uri = "mongodb://tenet_api:6k5s0g20rMb6wCMe@tenet-shard-00-00.vm7su.mongodb.net:27017,tenet-shard-00-01.vm7su.mongodb.net:27017,tenet-shard-00-02.vm7su.mongodb.net:27017/tenet?ssl=true&replicaSet=atlas-30piss-shard-0&authSource=admin&retryWrites=true&w=majority"
# _db_name = "tenet"
# _db_doc = "tweets"
# client = pymongo.MongoClient(_mongo_uri)
# db = client[_db_name]
# doc = db[_db_doc]

# # Fetch data
# _obj = {"polarity == trans_polarity"}
# # { "$expr": { "$ne": [ "$polarity" , "$trans_polarity" ] } }
# tweets = doc.find()

# with open('dataset.csv', mode='w') as file:
#     writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#     # header
#     writer.writerow(['S. No.', 'Text', 'Trasnlated Text', 'Lang Tag', 'Polarity', 'Trasnlated Polarity'])
#     _count = 1
#     for row in tweets:        
#         try:
#             writer.writerow([_count, row['tweet'], row['trans_text'], row['lang'], row['polarity'], row['trans_polarity']])
#             _count += 1
#             print(_count, end=",")
#         except:
#             continue        
# print("CSV Closed!!")
